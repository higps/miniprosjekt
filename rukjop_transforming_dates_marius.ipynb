# %%
import pandas as pd

# %%
df_original_sales_train = pd.read_csv("sales_train.csv")

# %%
df_draft_sales_trian = df_original_sales_train.copy()

# %%
df_original_transformed = pd.read_csv("rukjop_transformed.csv")

# %%
df_draft_transformed = df_original_transformed.copy()

# %%
df_calendar = pd.read_csv('calender.csv')

# %%
df_calendar_transformed = df_calendar.copy()

# %%
# Convert the 'Date' column to datetime
df_calendar_transformed['date'] = pd.to_datetime(df_calendar_transformed['date'])

# Change the date format to DD.MM.YYYY
df_calendar_transformed['Date_formatted'] = df_calendar_transformed['date'].dt.strftime('%d.%m.%Y')
df_calendar_transformed.to_csv('calendar_formatted.csv')
# Drop the original 'Date' column if not needed
# df_calendar_transformed = df_calendar_transformed.drop('Date', axis=1)

# %%
df_calendar_transformed.head()
# Out:
#         date   day_name  day_of_week  day_of_month  week month_name  \
# 0 2013-01-01    Tuesday            1             1     1    January
# 1 2013-01-02  Wednesday            2             2     1    January
# 2 2013-01-03   Thursday            3             3     1    January
# 3 2013-01-04     Friday            4             4     1    January
# 4 2013-01-05   Saturday            5             5     1    January
#
#    month_of_year month_year_name  month_year_name_sort  quarter  \
# 0              1    January 2013                201301        1
# 1              1    January 2013                201301        1
# 2              1    January 2013                201301        1
# 3              1    January 2013                201301        1
# 4              1    January 2013                201301        1
#
#    quarter_year_name_sort  year  year_half  red_day_not_sun  black_friday  \
# 0                   20131  2013          1                1             0
# 1                   20131  2013          1                1             0
# 2                   20131  2013          1                1             0
# 3                   20131  2013          1                1             0
# 4                   20131  2013          1                0             0
#
#   Date_formatted
# 0     01.01.2013
# 1     02.01.2013
# 2     03.01.2013
# 3     04.01.2013
# 4     05.01.2013

# %%
df_original_sales_train.head()
# Out:
#          date  date_block_num  shop_id  item_id  item_price  item_cnt_day
# 0  02.01.2013               0       59    22154      999.00           1.0
# 1  03.01.2013               0       25     2552      899.00           1.0
# 2  05.01.2013               0       25     2552      899.00          -1.0
# 3  06.01.2013               0       25     2554     1709.05           1.0
# 4  15.01.2013               0       25     2555     1099.00           1.0

# %%
# Date_formatted on date

df_date = pd.merge(df_draft_sales_trian, df_calendar_transformed, left_on=["date"], right_on=["Date_formatted"], how="left")
df_date = df_date.sort_values("Date_formatted", ascending=False)

# %%
df_date.to_csv('sales_train_dates_added.csv')

# %%
df_draft_transformed["date_block_num_lag"] = df_draft_transformed["date_block_num"] + 1

# %%
features = ["date_block_num","date_block_num_lag","item_cnt_day"]
y = df_draft_transformed["item_cnt_day"]
df_new = df_draft_transformed[features]

# %%
df_lag = pd.merge(df_draft_sales_trian, df_draft_transformed, left_on=["date_block_num", "item_id", "shop_id"], right_on=["date_block_num_lag", "item_id", "shop_id"], how="left")
df_lag = df_lag.sort_values("item_cnt_day_x", ascending=False)
df_lag
# Out:
#                date  date_block_num_x  shop_id  item_id   item_price  \
# 2909818  28.10.2015                33       12    11373     0.908714
# 2326930  15.01.2015                24       12    20949     4.000000
# 2864235  30.09.2015                32       12     9248  1692.526158
# 2851091  30.09.2015                32       55     9249  1702.825746
# 2608040  14.04.2015                27       12     3731  1904.548077
# ...             ...               ...      ...      ...          ...
# 59156    18.01.2013                 0       12     1590  2599.000000
# 940092   19.10.2013                 9       42     3732  2599.000000
# 2048519  10.10.2014                21       12     9242  1433.333333
# 1835454  10.07.2014                18       14    20949     5.000000
# 1057907  02.11.2013                10       12     8023    15.000000
#
#          item_cnt_day_x  Unnamed: 0  date_block_num_y  item_cnt_day_y  \
# 2909818          2169.0  10567093.0              32.0           246.0
# 2326930          1000.0   8410351.0              23.0           500.0
# 2864235           669.0  10328134.0              31.0            19.0
# 2851091           637.0  10328204.0              31.0            19.0
# 2608040           624.0         NaN               NaN             NaN
# ...                 ...         ...               ...             ...
# 59156              -6.0         NaN               NaN             NaN
# 940092             -6.0   3062771.0               8.0           432.0
# 2048519            -9.0   7275151.0              20.0           904.0
# 1835454           -16.0   6478506.0              17.0            88.0
# 1057907           -22.0   3481113.0               9.0             0.0
#
#          date_block_num_lag
# 2909818                33.0
# 2326930                24.0
# 2864235                32.0
# 2851091                32.0
# 2608040                 NaN
# ...                     ...
# 59156                   NaN
# 940092                  9.0
# 2048519                21.0
# 1835454                18.0
# 1057907                10.0
#
# [2935849 rows x 10 columns]

# %%
import generate_month as gm


# for i in (df_lag["date_block_num_lag"].tolist()):
#     df_lag["Month_Name"] = gm.int_to_month(i)

# %%
df_lag['month_column_name'] = df_lag['date_block_num_lag'].apply(gm.int_to_month)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\MariusDyrseth\Documents\mini prosjekt\miniprosjekt\rukjop_pandas_marius.ipynb Cell 12 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/MariusDyrseth/Documents/mini%20prosjekt/miniprosjekt/rukjop_pandas_marius.ipynb#X25sZmlsZQ%3D%3D?line=0'>1</a> df_lag['month_column_name'] = df_lag['date_block_num_lag'].apply(gm.int_to_month)
#
# File c:\Users\MariusDyrseth\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\series.py:4760, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4625 def apply(
#    4626     self,
#    4627     func: AggFuncType,
#    (...)
#    4632     **kwargs,
#    4633 ) -> DataFrame | Series:
#    4634     """
#    4635     Invoke function on values of Series.
#    4636
#    (...)
#    4751     dtype: float64
#    4752     """
#    4753     return SeriesApply(
#    4754         self,
#    4755         func,
#    4756         convert_dtype=convert_dtype,
#    4757         by_row=by_row,
#    4758         args=args,
#    4759         kwargs=kwargs,
# -> 4760     ).apply()
#
# File c:\Users\MariusDyrseth\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\apply.py:1207, in SeriesApply.apply(self)
#    1204     return self.apply_compat()
#    1206 # self.func is Callable
# -> 1207 return self.apply_standard()
#
# File c:\Users\MariusDyrseth\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\apply.py:1287, in SeriesApply.apply_standard(self)
#    1281 # row-wise access
#    1282 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1283 # we need to give `na_action="ignore"` for categorical data.
#    1284 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1285 #  Categorical (GH51645).
#    1286 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1287 mapped = obj._map_values(
#    1288     mapper=curried, na_action=action, convert=self.convert_dtype
#    1289 )
#    1291 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1292     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1293     #  See also GH#25959 regarding EA support
#    1294     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File c:\Users\MariusDyrseth\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File c:\Users\MariusDyrseth\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\algorithms.py:1814, in map_array(arr, mapper, na_action, convert)
#    1812 values = arr.astype(object, copy=False)
#    1813 if na_action is None:
# -> 1814     return lib.map_infer(values, mapper, convert=convert)
#    1815 else:
#    1816     return lib.map_infer_mask(
#    1817         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1818     )
#
# File lib.pyx:2920, in pandas._libs.lib.map_infer()
#
# File c:\Users\MariusDyrseth\Documents\mini prosjekt\miniprosjekt\generate_month.py:17, in int_to_month(value)
#      10 months = [
#      11     "Jan", "Feb", "Mar", "Apr",
#      12     "May", "Jun", "Jul", "Aug",
#      13     "Sep", "Oct", "Nov", "Dec"
#      14 ]
#      16 # Return the corresponding month as uppercase
# ---> 17 return months[value - 1].upper()
#
# TypeError: list indices must be integers or slices, not float

# %%
df_lag.to_csv('date_month_display_number.csv')
